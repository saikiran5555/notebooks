# %%
# Step 1: Import required libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Step 2: Fetch Tesla stock data using yfinance
tesla = yf.Ticker("TSLA")

# Get historical market data for Tesla
historical_data = tesla.history(period="1y")  # Last 1 year

# Step 3: Fetch Tesla revenue data
# Revenue data can be extracted directly from the yfinance object
financials = tesla.financials

# Step 4: Prepare revenue data for visualization
# Transpose the financials DataFrame for better readability
tesla_financials = tesla.financials
revenue = tesla_financials.loc['Total Revenue']

# Step 5: Create a dashboard
plt.figure(figsize=(14, 6))

# Plot stock price
plt.subplot(1, 2, 1)
plt.plot(historical_data.index, historical_data['Close'], label='Tesla Stock Price', color='blue')
plt.title('Tesla Stock Price Over the Last Year')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.xticks(rotation=45)
plt.legend()

# Plot revenue
plt.subplot(1, 2, 2)
plt.bar(revenue_df.index, revenue_df.values, color='orange')
plt.title('Tesla Revenue')
plt.xlabel('Quarter')
plt.ylabel('Revenue (USD)')
plt.xticks(rotation=45)

# Show the dashboard
plt.tight_layout()
plt.show()
